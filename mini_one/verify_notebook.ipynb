# %% [markdown]
# # VS Code Python and Jupyter Verification
# This notebook verifies that a Python cell executes in the open project.

# %%
import sys
from pathlib import Path

print("Jupyter notebook cell executed successfully")
print(f"Python version: {sys.version.split()[0]}")
print(f"Notebook Python executable: {sys.executable}")
print(f"Notebook project directory: {Path.cwd()}")
# Out:
# Jupyter notebook cell executed successfully
# Python version: 3.13.5
# Notebook Python executable: /Users/jakobbrown/School/CyML/IT7075/mini_one/.venv/bin/python
# Notebook project directory: /Users/jakobbrown/School/CyML/IT7075/mini_one
